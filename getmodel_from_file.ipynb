# %%
import joblib

model = joblib.load('newmodel.joblib')

pre = model.predict([[21,1]])

print(pre)S
# Out:
# ['HipHop']
# c:\Users\User\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
